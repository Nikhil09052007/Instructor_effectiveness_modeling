# %% [markdown]
# # **Instructor Effectiveness Modeling (EdTech Context)**
#
# ## Part 1: Data Ingestion and Preparation
#
# Loading the dataset and inspecting every column one by one (shape, dtypes, nulls, duplicates, unique values).
#
# **Notebooks in this project:**
#
# 1. `01_Data_Ingestion_and_Preparation.ipynb` &nbsp;&larr; *you are here*
# 2. `02_Data_Interpretation_and_EDA.ipynb`
# 3. `03_Instructor_Level_Aggregation.ipynb`
# 4. `04_Machine_Learning_Model.ipynb`
# 5. `05_Model_Evaluation.ipynb`
# 6. `06_Interpretation_and_Analysis_Questions.ipynb`
#
# ---

# %% [markdown]
# # Part 1: Data Ingestion and Preparation
#
# ---

# %% [markdown]
# # **Instructor Effectiveness Modeling (EdTech Context) Project**

# %% [markdown]
# # **Analysing the dataset and performing**

# %%
# Importing some libraries for data manipulation and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r'C:\Users\acer\Desktop\Programs\Accredian-Assignment\data\instructor_effectiveness_dataset_2000_rows - instructor_effectiveness_dataset_2000_rows.csv.csv')  # Load the dataset

# %%
data
# Out:
#      batch_id instructor_id course_id  completion_rate  avg_score_improvement  \
# 0      B_1861         I_044      C_01         0.300000              14.225955
# 1      B_0354         I_119      C_06         0.657220              22.871110
# 2      B_1334         I_050      C_03         0.300000              16.087517
# 3      B_0906         I_024      C_21         0.639507              24.260687
# 4      B_1290         I_001      C_08         0.527302              31.081556
# ...       ...           ...       ...              ...                    ...
# 1995   B_1131         I_047      C_17         0.589309              19.227979
# 1996   B_1295         I_037      C_25         0.980000              36.737265
# 1997   B_0861         I_033      C_06         0.531447              24.907878
# 1998   B_1460         I_069      C_10         0.641025              22.395362
# 1999   B_1127         I_045      C_22         0.300000              23.101794
#
# ...

# %%
# Looking inside the dataset to understand its structure and contents
data.head()  # Display the first few rows of the dataset
# Out:
#   batch_id instructor_id course_id  completion_rate  avg_score_improvement  \
# 0   B_1861         I_044      C_01         0.300000              14.225955
# 1   B_0354         I_119      C_06         0.657220              22.871110
# 2   B_1334         I_050      C_03         0.300000              16.087517
# 3   B_0906         I_024      C_21         0.639507              24.260687
# 4   B_1290         I_001      C_08         0.527302              31.081556
#
#    avg_quiz_score  dropout_rate  avg_watch_time  assignment_submission_rate  \
# 0       73.546528      0.647423        0.774572                    0.790918
# 1       77.312331      0.425098        0.494936                    0.998566
# 2       79.563687      0.700000        0.977901                    0.807298
# 3       99.295316      0.334657        0.846515                    0.544555
# 4       99.393425      0.521099        0.917450                    0.865885
#
# ...

# %%
# info about the dataset
data.info()  # Get information about the dataset, including data types and non-null counts
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   batch_id                    2000 non-null   str
#  1   instructor_id               2000 non-null   str
#  2   course_id                   2000 non-null   str
#  3   completion_rate             2000 non-null   float64
#  4   avg_score_improvement       2000 non-null   float64
#  5   avg_quiz_score              2000 non-null   float64
#  6   dropout_rate                2000 non-null   float64
#  7   avg_watch_time              2000 non-null   float64
#  8   assignment_submission_rate  2000 non-null   float64
#  9   forum_activity_rate         2000 non-null   float64
#  10  avg_feedback_score          2000 non-null   float64
#  11  feedback_response_rate      2000 non-null   float64
# dtypes: float64(9), str(3)
# memory usage: 187.6 KB

# %%
data.shape # Get the shape of the dataset (number of rows and columns)
# Out:
# (2000, 12)

# %%
#Looking into the columns of the dataset to understand the features available for analysis
data.columns.to_list()  # List the column names in the dataset
# Out:
# ['batch_id',
#  'instructor_id',
#  'course_id',
#  'completion_rate',
#  'avg_score_improvement',
#  'avg_quiz_score',
#  'dropout_rate',
#  'avg_watch_time',
#  'assignment_submission_rate',
#  'forum_activity_rate',
#  'avg_feedback_score',
#  'feedback_response_rate']

# %%
# Checking for missing values in the dataset to identify any data quality issues
data.isnull().sum()  # Count the number of missing values in each column
# Out:
# batch_id                      0
# instructor_id                 0
# course_id                     0
# completion_rate               0
# avg_score_improvement         0
# avg_quiz_score                0
# dropout_rate                  0
# avg_watch_time                0
# assignment_submission_rate    0
# forum_activity_rate           0
# avg_feedback_score            0
# feedback_response_rate        0
# dtype: int64

# %%
data.isnull().sum() # Get the total number of missing values in the entire dataset
# Out:
# batch_id                      0
# instructor_id                 0
# course_id                     0
# completion_rate               0
# avg_score_improvement         0
# avg_quiz_score                0
# dropout_rate                  0
# avg_watch_time                0
# assignment_submission_rate    0
# forum_activity_rate           0
# avg_feedback_score            0
# feedback_response_rate        0
# dtype: int64

# %%
#Looking for duplicates in the dataset to ensure data integrity
data.duplicated().sum()  # Count the number of duplicate rows in the dataset
# Out:
# np.int64(0)

# %%
# Looking for statistical summary of the dataset to understand the distribution of numerical features
data.describe()  # Generate a statistical summary of the numerical columns in the dataset
# Out:
#        completion_rate  avg_score_improvement  avg_quiz_score  dropout_rate  \
# count      2000.000000            2000.000000     2000.000000   2000.000000
# mean          0.602808              27.035844       77.956126      0.394883
# std           0.159667               5.716641       10.695618      0.162747
# min           0.300000               6.159240       40.386725      0.020000
# 25%           0.489260              23.124673       70.897590      0.280035
# 50%           0.603091              26.938629       78.020567      0.394820
# 75%           0.712797              30.885600       85.444286      0.511432
# max           0.980000              40.000000      100.000000      0.700000
#
#        avg_watch_time  assignment_submission_rate  forum_activity_rate  \
# count     2000.000000                 2000.000000          2000.000000
# mean         0.776515                    0.753188             0.250300
# ...

# %% [markdown]
# # **Interpretation for dataset:**

# %% [markdown]
# # So, here is the breakdown for the whole dataset given:
#
# * **Our dataset contains of 2000 rows and 12 columns of several features consisting thier values.**
# * **After looking through the dataset, I haven't found any of the null values in any of the columns.**
# * **I haven't found any duplicated data too in the dataset.**
#
# # Here, I'm tending towards the column wise interpretation of this dataset:
#
# **Our columns are classifies as:**
#
# * 'batch_id',
# *  'instructor_id',
# * 'course_id',
# * 'completion_rate',
# * 'avg_score_improvement',
# * 'avg_quiz_score',
# * 'dropout_rate',
# * 'avg_watch_time',
# * 'assignment_submission_rate',
# * 'forum_activity_rate',
# * 'avg_feedback_score',
# * 'feedback_response_rate'

# %% [markdown]
# # **1.batch_id**

# %%
data['batch_id'].head(10)
# Out:
# 0    B_1861
# 1    B_0354
# 2    B_1334
# 3    B_0906
# 4    B_1290
# 5    B_1274
# 6    B_0939
# 7    B_1732
# 8    B_0066
# 9    B_1324
# Name: batch_id, dtype: str

# %%
# batch_id column is a categorical feature, so we can look at the unique values and their counts to understand its distribution
data['batch_id'].value_counts().sum()  # Count the occurrences of each unique value
# Out:
# np.int64(2000)

# %%
data['batch_id'].nunique()  # Count the number of unique values in the 'batch_id' column
# Out:
# 2000

# %%
data['batch_id'].value_counts()  # Get the counts of each unique value in the 'batch_id' column
# Out:
# batch_id
# B_1861    1
# B_0354    1
# B_1334    1
# B_0906    1
# B_1290    1
#          ..
# B_1131    1
# B_1295    1
# B_0861    1
# B_1460    1
# B_1127    1
# Name: count, Length: 2000, dtype: int64

# %%
data['batch_id'].isnull().sum()  # Count the number of missing values in the 'batch_id' column
# Out:
# np.int64(0)

# %%
data['batch_id'].duplicated().sum() # Checking for duplicate values
# Out:
# np.int64(0)

# %%
data['batch_id'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# # **2.instructor_id**

# %%
data['instructor_id'].head()
# Out:
# 0    I_044
# 1    I_119
# 2    I_050
# 3    I_024
# 4    I_001
# Name: instructor_id, dtype: str

# %%
data['instructor_id'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: instructor_id, Length: 2000, dtype: bool

# %%
data['instructor_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['instructor_id'].nunique()
# Out:
# 120

# %%
data['instructor_id'].duplicated().sum()  # Duplications mean some instructors are same
# Out:
# np.int64(1880)

# %%
data['instructor_id'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# # **3.course_id**

# %%
data['course_id'].head()
# Out:
# 0    C_01
# 1    C_06
# 2    C_03
# 3    C_21
# 4    C_08
# Name: course_id, dtype: str

# %%
data['course_id'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['course_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['course_id'].nunique()
# Out:
# 25

# %%
data['course_id'].duplicated().sum()
# Out:
# np.int64(1975)

# %%
data['course_id'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# # **4.completion_rate**

# %%
data['completion_rate'].head()
# Out:
# 0    0.300000
# 1    0.657220
# 2    0.300000
# 3    0.639507
# 4    0.527302
# Name: completion_rate, dtype: float64

# %%
data['completion_rate'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['completion_rate'].isnull().sum(
)
# Out:
# np.int64(0)

# %%
data['completion_rate'].nunique()
# Out:
# 1893

# %%
data['completion_rate'].duplicated()
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1995    False
# 1996     True
# 1997    False
# 1998    False
# 1999     True
# Name: completion_rate, Length: 2000, dtype: bool

# %%
data['completion_rate'].duplicated().sum()
# Out:
# np.int64(107)

# %%
data['completion_rate'].dtype
# Out:
# dtype('float64')

# %%
data['completion_rate'].mean()
# Out:
# np.float64(0.60280821072425)

# %% [markdown]
# # **5.avg_score_improvement**

# %%
data['avg_score_improvement'].head()
# Out:
# 0    14.225955
# 1    22.871110
# 2    16.087517
# 3    24.260687
# 4    31.081556
# Name: avg_score_improvement, dtype: float64

# %%
data['avg_score_improvement'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['avg_score_improvement'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['avg_score_improvement'].unique()
# Out:
# array([14.22595478, 22.87111044, 16.08751744, ..., 24.90787778,
#        22.39536245, 23.10179394], shape=(1966,))

# %%
data['avg_score_improvement'].duplicated().sum()
# Out:
# np.int64(34)

# %%
data['avg_score_improvement'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # **6.avg_quiz_score**

# %%
data['avg_quiz_score'].head()
# Out:
# 0    73.546528
# 1    77.312331
# 2    79.563687
# 3    99.295316
# 4    99.393425
# Name: avg_quiz_score, dtype: float64

# %%
data['avg_quiz_score'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['avg_quiz_score'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['avg_quiz_score'].unique()
# Out:
# array([73.54652768, 77.31233097, 79.56368722, ..., 83.99069275,
#        80.04423142, 86.89115327], shape=(1964,))

# %%
data['avg_quiz_score'].duplicated().sum()
# Out:
# np.int64(36)

# %%
data['avg_quiz_score'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # **7.dropout_rate**

# %%
data['dropout_rate'].head()
# Out:
# 0    0.647423
# 1    0.425098
# 2    0.700000
# 3    0.334657
# 4    0.521099
# Name: dropout_rate, dtype: float64

# %%
data['dropout_rate'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['dropout_rate'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['dropout_rate'].unique()
# Out:
# array([0.6474233 , 0.42509791, 0.7       , ..., 0.10356106, 0.51226558,
#        0.31723111], shape=(1907,))

# %%
data['dropout_rate'].duplicated().sum()
# Out:
# np.int64(93)

# %%
data['dropout_rate'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # **8.avg_watch_time**

# %%
data['avg_watch_time'].head()
# Out:
# 0    0.774572
# 1    0.494936
# 2    0.977901
# 3    0.846515
# 4    0.917450
# Name: avg_watch_time, dtype: float64

# %%
data['avg_watch_time'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['avg_watch_time'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['avg_watch_time'].unique()
# Out:
# array([0.7745723 , 0.49493597, 0.97790127, ..., 0.91892354, 0.55818265,
#        0.56383425], shape=(1852,))

# %%
data['avg_watch_time'].duplicated().sum()
# Out:
# np.int64(148)

# %%
data['avg_watch_time'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # **9.assignment_submission_rate**

# %%
data.columns
# Out:
# Index(['batch_id', 'instructor_id', 'course_id', 'completion_rate',
#        'avg_score_improvement', 'avg_quiz_score', 'dropout_rate',
#        'avg_watch_time', 'assignment_submission_rate', 'forum_activity_rate',
#        'avg_feedback_score', 'feedback_response_rate'],
#       dtype='str')

# %%
data['assignment_submission_rate'].head()
# Out:
# 0    0.790918
# 1    0.998566
# 2    0.807298
# 3    0.544555
# 4    0.865885
# Name: assignment_submission_rate, dtype: float64

# %%
data['assignment_submission_rate'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['assignment_submission_rate'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['assignment_submission_rate'].unique()
# Out:
# array([0.79091815, 0.99856607, 0.80729783, ..., 0.59827581, 0.57562905,
#        0.53869144], shape=(1876,))

# %%
data['assignment_submission_rate'].duplicated().sum()
# Out:
# np.int64(124)

# %%
data['assignment_submission_rate'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # **10.forum_activity_rate**

# %%
data['forum_activity_rate'].head()
# Out:
# 0    0.108414
# 1    0.280550
# 2    0.207013
# 3    0.306395
# 4    0.252289
# Name: forum_activity_rate, dtype: float64

# %%
data['forum_activity_rate'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['forum_activity_rate'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['forum_activity_rate'].unique()
# Out:
# array([0.108414  , 0.28054969, 0.20701347, ..., 0.27170091, 0.1354996 ,
#        0.210189  ], shape=(1987,))

# %%
data['forum_activity_rate'].duplicated().sum()
# Out:
# np.int64(13)

# %% [markdown]
# # **11.avg_feedback_score**

# %%
data['avg_feedback_score'].head()
# Out:
# 0    3.766211
# 1    5.000000
# 2    3.517386
# 3    4.207578
# 4    4.426230
# Name: avg_feedback_score, dtype: float64

# %%
data['avg_feedback_score'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['avg_feedback_score'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['avg_feedback_score'].unique()
# Out:
# array([3.7662115 , 5.        , 3.5173863 , ..., 4.21111264, 4.18214062,
#        4.4203085 ], shape=(1934,))

# %%
data['avg_feedback_score'].duplicated().sum()
# Out:
# np.int64(66)

# %% [markdown]
# # **12.feedback_response_rate**

# %%
data['feedback_response_rate'].head()
# Out:
# 0    0.533193
# 1    0.734087
# 2    0.681433
# 3    1.000000
# 4    0.696710
# Name: feedback_response_rate, dtype: float64

# %%
data['feedback_response_rate'].value_counts().sum()
# Out:
# np.int64(2000)

# %%
data['feedback_response_rate'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['feedback_response_rate'].unique()
# Out:
# array([0.53319304, 0.73408742, 0.68143322, ..., 0.77343665, 0.96262685,
#        0.54561111], shape=(1907,))

# %%
data['feedback_response_rate'].duplicated().sum()
# Out:
# np.int64(93)
